# %% [markdown]
# # LSTM Sign Language Detection by Avishake Adhikary
#
# ![Amity University](https://upload.wikimedia.org/wikipedia/en/thumb/d/df/Amity_University_Kolkata.svg/1200px-Amity_University_Kolkata.svg.png)
#
# ## Masters of Computer Applications
# ## Amity University Kolkata
# #### Under the guidance of Prof. Soma Debnath

# %% [markdown]
# **LSTM MODEL**
# 1. Install and import dependencies
# 2. Keypoints using MP Holistic
# 3. Extract Keypoints
# 4. Setup Folders for Collection
# 5. Collect Keypoints Values for Training and Testing
# 6. Preprocess Data and Create Labels and Features
# 7. Build and Train LSTM Neural Network
# 8. Make Predictions
# 9. Save Weights
# 10. Evaluation using Confusion Matrix and Accuracy
# 11. Test in Real Time

# %% [markdown]
# # Install and Import Dependencies

# %%
# !uv pip install tensorflow opencv-python mediapipe scikit-learn matplotlib tensorflowjs
# Out:
# Audited 6 packages in 79ms

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Extract Keypoint Values

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['cat', 'food', 'help'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
signs = ['cat','food','help']

parent_folder = 'MP_Data'

if not os.path.exists(parent_folder):
    os.mkdir(parent_folder)
    for sign in signs:
        sign_folder = os.path.join(parent_folder, sign)
        os.mkdir(sign_folder)
        for i in range(30):
            subfolder = os.path.join(sign_folder, str(i))
            os.mkdir(subfolder)

# %% [markdown]
# # Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'cat': 0, 'food': 1, 'help': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# # Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
#While training access tensorboard
#tensorboard --logdir=.

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - categorical_accuracy: 0.9882 - loss: 0.1058
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - categorical_accuracy: 0.9647 - loss: 0.1561
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - categorical_accuracy: 0.9765 - loss: 0.1491
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - categorical_accuracy: 0.9647 - loss: 0.1106
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - categorical_accuracy: 0.9882 - loss: 0.1295
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 466ms/step - categorical_accuracy: 0.9765 - loss: 0.0780
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - categorical_accuracy: 0.9765 - loss: 0.1121
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - categorical_accuracy: 0.9882 - loss: 0.0886
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step - categorical_accuracy: 0.9647 - loss: 0.1103
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - categorical_accuracy: 0.9882 - loss: 0.0890
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - categorical_accuracy: 0.9882 - loss: 0.0761
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - categorical_accuracy: 0.9882 - loss: 0.0752
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - categorical_accuracy: 0.9882 - loss: 0.0678
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - categorical_accuracy: 0.9882 - loss: 0.0666
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - categorical_accuracy: 0.9765 - loss: 0.0757
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - categorical_accuracy: 0.9882 - loss: 0.0649
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - categorical_accuracy: 0.9765 - loss: 0.0956
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - categorical_accuracy: 0.9765 - loss: 0.1193
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - categorical_accuracy: 0.9647 - loss: 0.1385
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - categorical_accuracy: 0.9765 - loss: 0.0793
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - categorical_accuracy: 0.9765 - loss: 0.1270
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - categorical_accuracy: 0.9176 - loss: 0.2077
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 305ms/step - categorical_accuracy: 0.8118 - loss: 0.6072
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - categorical_accuracy: 0.6235 - loss: 3.2338
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step
2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.2075e-06 - categorical_accuracy: 1.0000
# Epoch 452/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.2033e-06 - categorical_accuracy: 1.0000
# Epoch 453/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 1.1963e-06 - categorical_accuracy: 1.0000
# Epoch 454/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 1.1879e-06 - categorical_accuracy: 1.0000
# Epoch 455/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.1837e-06 - categorical_accuracy: 1.0000
# Epoch 456/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.1809e-06 - categorical_accuracy: 1.0000
# Epoch 457/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.1711e-06 - categorical_accuracy: 1.0000
# Epoch 458/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.1697e-06 - categorical_accuracy: 1.0000
# Epoch 459/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.1598e-06 - categorical_accuracy: 1.0000
# Epoch 460/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.1528e-06 - categorical_accuracy: 1.0000
# Epoch 461/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1500e-06 - categorical_accuracy: 1.0000
# Epoch 462/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.1430e-06 - categorical_accuracy: 1.0000
# Epoch 463/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.1374e-06 - categorical_accuracy: 1.0000
# Epoch 464/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1318e-06 - categorical_accuracy: 1.0000
# Epoch 465/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.1220e-06 - categorical_accuracy: 1.0000
# Epoch 466/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.1206e-06 - categorical_accuracy: 1.0000
# Epoch 467/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.1164e-06 - categorical_accuracy: 1.0000
# Epoch 468/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1107e-06 - categorical_accuracy: 1.0000
# Epoch 469/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.1037e-06 - categorical_accuracy: 1.0000
# Epoch 470/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.1023e-06 - categorical_accuracy: 1.0000
# Epoch 471/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0953e-06 - categorical_accuracy: 1.0000
# Epoch 472/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0883e-06 - categorical_accuracy: 1.0000
# Epoch 473/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0855e-06 - categorical_accuracy: 1.0000
# Epoch 474/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0813e-06 - categorical_accuracy: 1.0000
# Epoch 475/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0771e-06 - categorical_accuracy: 1.0000
# Epoch 476/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0701e-06 - categorical_accuracy: 1.0000
# Epoch 477/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0631e-06 - categorical_accuracy: 1.0000
# Epoch 478/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0589e-06 - categorical_accuracy: 1.0000
# Epoch 479/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0490e-06 - categorical_accuracy: 1.0000
# Epoch 480/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0434e-06 - categorical_accuracy: 1.0000
# Epoch 481/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0420e-06 - categorical_accuracy: 1.0000
# Epoch 482/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0364e-06 - categorical_accuracy: 1.0000
# Epoch 483/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0294e-06 - categorical_accuracy: 1.0000
# Epoch 484/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0266e-06 - categorical_accuracy: 1.0000
# Epoch 485/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0252e-06 - categorical_accuracy: 1.0000
# Epoch 486/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0238e-06 - categorical_accuracy: 1.0000
# Epoch 487/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0182e-06 - categorical_accuracy: 1.0000
# Epoch 488/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0112e-06 - categorical_accuracy: 1.0000
# Epoch 489/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0084e-06 - categorical_accuracy: 1.0000
# Epoch 490/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0014e-06 - categorical_accuracy: 1.0000
# Epoch 491/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 9.9995e-07 - categorical_accuracy: 1.0000
# Epoch 492/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 9.9294e-07 - categorical_accuracy: 1.0000
# Epoch 493/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 9.8453e-07 - categorical_accuracy: 1.0000
# Epoch 494/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 9.7892e-07 - categorical_accuracy: 1.0000
# Epoch 495/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 9.7751e-07 - categorical_accuracy: 1.0000
# Epoch 496/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 9.7190e-07 - categorical_accuracy: 1.0000
# Epoch 497/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 9.6910e-07 - categorical_accuracy: 1.0000
# Epoch 498/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 9.6489e-07 - categorical_accuracy: 1.0000
# Epoch 499/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.6209e-07 - categorical_accuracy: 1.0000
# Epoch 500/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 9.5648e-07 - categorical_accuracy: 1.0000
# Epoch 501/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 9.5227e-07 - categorical_accuracy: 1.0000
# Epoch 502/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 9.4526e-07 - categorical_accuracy: 1.0000
# Epoch 503/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 9.4245e-07 - categorical_accuracy: 1.0000
# Epoch 504/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 9.4105e-07 - categorical_accuracy: 1.0000
# Epoch 505/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 9.3404e-07 - categorical_accuracy: 1.0000
# Epoch 506/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 9.3264e-07 - categorical_accuracy: 1.0000
# Epoch 507/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 9.2983e-07 - categorical_accuracy: 1.0000
# Epoch 508/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 9.2422e-07 - categorical_accuracy: 1.0000
# Epoch 509/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.2001e-07 - categorical_accuracy: 1.0000
# Epoch 510/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 9.1721e-07 - categorical_accuracy: 1.0000
# Epoch 511/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 9.0879e-07 - categorical_accuracy: 1.0000
# Epoch 512/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 9.0459e-07 - categorical_accuracy: 1.0000
# Epoch 513/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 8.9898e-07 - categorical_accuracy: 1.0000
# Epoch 514/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 8.9477e-07 - categorical_accuracy: 1.0000
# Epoch 515/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 8.9056e-07 - categorical_accuracy: 1.0000
# Epoch 516/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 8.8635e-07 - categorical_accuracy: 1.0000
# Epoch 517/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 8.8355e-07 - categorical_accuracy: 1.0000
# Epoch 518/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 8.7373e-07 - categorical_accuracy: 1.0000
# Epoch 519/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 8.7233e-07 - categorical_accuracy: 1.0000
# Epoch 520/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 8.7093e-07 - categorical_accuracy: 1.0000
# Epoch 521/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 8.6953e-07 - categorical_accuracy: 1.0000
# Epoch 522/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 8.6672e-07 - categorical_accuracy: 1.0000
# Epoch 523/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 8.6392e-07 - categorical_accuracy: 1.0000
# Epoch 524/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 8.6251e-07 - categorical_accuracy: 1.0000
# Epoch 525/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 8.5971e-07 - categorical_accuracy: 1.0000
# Epoch 526/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 8.5410e-07 - categorical_accuracy: 1.0000
# Epoch 527/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 8.4428e-07 - categorical_accuracy: 1.0000
# Epoch 528/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 8.4148e-07 - categorical_accuracy: 1.0000
# Epoch 529/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 8.3727e-07 - categorical_accuracy: 1.0000
# Epoch 530/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 8.3446e-07 - categorical_accuracy: 1.0000
# Epoch 531/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 8.3026e-07 - categorical_accuracy: 1.0000
# Epoch 532/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 8.2745e-07 - categorical_accuracy: 1.0000
# Epoch 533/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 8.2324e-07 - categorical_accuracy: 1.0000
# Epoch 534/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 8.2184e-07 - categorical_accuracy: 1.0000
# Epoch 535/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 8.1763e-07 - categorical_accuracy: 1.0000
# Epoch 536/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 8.1343e-07 - categorical_accuracy: 1.0000
# Epoch 537/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 8.1202e-07 - categorical_accuracy: 1.0000
# Epoch 538/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 8.0922e-07 - categorical_accuracy: 1.0000
# Epoch 539/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 8.0221e-07 - categorical_accuracy: 1.0000
# Epoch 540/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 7.9940e-07 - categorical_accuracy: 1.0000
# Epoch 541/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 7.9800e-07 - categorical_accuracy: 1.0000
# Epoch 542/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.9660e-07 - categorical_accuracy: 1.0000
# Epoch 543/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.9379e-07 - categorical_accuracy: 1.0000
# Epoch 544/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 7.8818e-07 - categorical_accuracy: 1.0000
# Epoch 545/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 7.8257e-07 - categorical_accuracy: 1.0000
# Epoch 546/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 7.7977e-07 - categorical_accuracy: 1.0000
# Epoch 547/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 7.7696e-07 - categorical_accuracy: 1.0000
# Epoch 548/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.7556e-07 - categorical_accuracy: 1.0000
# Epoch 549/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.7135e-07 - categorical_accuracy: 1.0000
# Epoch 550/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 7.6855e-07 - categorical_accuracy: 1.0000
# Epoch 551/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 7.6574e-07 - categorical_accuracy: 1.0000
# Epoch 552/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 7.6294e-07 - categorical_accuracy: 1.0000
# Epoch 553/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 7.5873e-07 - categorical_accuracy: 1.0000
# Epoch 554/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 7.5733e-07 - categorical_accuracy: 1.0000
# Epoch 555/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 7.4751e-07 - categorical_accuracy: 1.0000
# Epoch 556/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 7.4330e-07 - categorical_accuracy: 1.0000
# Epoch 557/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 7.4190e-07 - categorical_accuracy: 1.0000
# Epoch 558/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 7.4050e-07 - categorical_accuracy: 1.0000
# Epoch 559/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 7.3769e-07 - categorical_accuracy: 1.0000
# Epoch 560/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 7.3349e-07 - categorical_accuracy: 1.0000
# Epoch 561/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 7.3068e-07 - categorical_accuracy: 1.0000
# Epoch 562/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.2367e-07 - categorical_accuracy: 1.0000
# Epoch 563/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 7.2086e-07 - categorical_accuracy: 1.0000
# Epoch 564/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.2086e-07 - categorical_accuracy: 1.0000
# Epoch 565/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 7.1806e-07 - categorical_accuracy: 1.0000
# Epoch 566/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 7.1525e-07 - categorical_accuracy: 1.0000
# Epoch 567/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.1385e-07 - categorical_accuracy: 1.0000
# Epoch 568/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 7.1105e-07 - categorical_accuracy: 1.0000
# Epoch 569/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 7.0965e-07 - categorical_accuracy: 1.0000
# Epoch 570/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 7.0684e-07 - categorical_accuracy: 1.0000
# Epoch 571/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 7.0404e-07 - categorical_accuracy: 1.0000
# Epoch 572/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 6.9843e-07 - categorical_accuracy: 1.0000
# Epoch 573/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 6.9702e-07 - categorical_accuracy: 1.0000
# Epoch 574/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 6.9141e-07 - categorical_accuracy: 1.0000
# Epoch 575/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.9141e-07 - categorical_accuracy: 1.0000
# Epoch 576/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 6.9141e-07 - categorical_accuracy: 1.0000
# Epoch 577/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 6.8440e-07 - categorical_accuracy: 1.0000
# Epoch 578/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 6.8300e-07 - categorical_accuracy: 1.0000
# Epoch 579/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 6.8019e-07 - categorical_accuracy: 1.0000
# Epoch 580/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 6.7879e-07 - categorical_accuracy: 1.0000
# Epoch 581/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 6.7458e-07 - categorical_accuracy: 1.0000
# Epoch 582/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 6.6897e-07 - categorical_accuracy: 1.0000
# Epoch 583/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.6897e-07 - categorical_accuracy: 1.0000
# Epoch 584/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 6.6617e-07 - categorical_accuracy: 1.0000
# Epoch 585/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 6.6477e-07 - categorical_accuracy: 1.0000
# Epoch 586/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 6.6477e-07 - categorical_accuracy: 1.0000
# Epoch 587/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 6.6056e-07 - categorical_accuracy: 1.0000
# Epoch 588/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 6.5635e-07 - categorical_accuracy: 1.0000
# Epoch 589/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 6.5355e-07 - categorical_accuracy: 1.0000
# Epoch 590/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 6.5074e-07 - categorical_accuracy: 1.0000
# Epoch 591/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 6.4934e-07 - categorical_accuracy: 1.0000
# Epoch 592/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.4653e-07 - categorical_accuracy: 1.0000
# Epoch 593/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 6.4513e-07 - categorical_accuracy: 1.0000
# Epoch 594/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 6.4233e-07 - categorical_accuracy: 1.0000
# Epoch 595/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.4092e-07 - categorical_accuracy: 1.0000
# Epoch 596/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 6.3812e-07 - categorical_accuracy: 1.0000
# Epoch 597/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 6.3531e-07 - categorical_accuracy: 1.0000
# Epoch 598/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 6.3391e-07 - categorical_accuracy: 1.0000
# Epoch 599/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 6.3251e-07 - categorical_accuracy: 1.0000
# Epoch 600/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 6.2970e-07 - categorical_accuracy: 1.0000
# Epoch 601/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 6.2129e-07 - categorical_accuracy: 1.0000
# Epoch 602/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 6.1849e-07 - categorical_accuracy: 1.0000
# Epoch 603/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 6.1568e-07 - categorical_accuracy: 1.0000
# Epoch 604/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 6.1288e-07 - categorical_accuracy: 1.0000
# Epoch 605/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.0867e-07 - categorical_accuracy: 1.0000
# Epoch 606/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 6.0727e-07 - categorical_accuracy: 1.0000
# Epoch 607/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 6.0166e-07 - categorical_accuracy: 1.0000
# Epoch 608/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 6.0025e-07 - categorical_accuracy: 1.0000
# Epoch 609/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 5.9885e-07 - categorical_accuracy: 1.0000
# Epoch 610/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 5.9464e-07 - categorical_accuracy: 1.0000
# Epoch 611/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 5.9324e-07 - categorical_accuracy: 1.0000
# Epoch 612/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 5.9184e-07 - categorical_accuracy: 1.0000
# Epoch 613/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 5.8903e-07 - categorical_accuracy: 1.0000
# Epoch 614/2000
# ...
# Epoch 1866/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 30, 64)              │         442,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 30, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,790,027 (6.83 MB)
#  Trainable params: 596,675 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,352 (4.55 MB)

# %%
# import visualkeras
# from PIL import ImageFont
# font = ImageFont.truetype("arial.ttf", 12)
# visualkeras.layered_view(model, legend=True, font=font,spacing=100)

# Install the required packages if they are not already installed
# !uv pip install visualkeras Pillow

# Now, import and run your code
import visualkeras
from PIL import ImageFont
font = ImageFont.truetype("arial.ttf", 12)
visualkeras.layered_view(model, legend=True, font=font,spacing=100)
# Out:
# Resolved 4 packages in 1.34s
# Prepared 2 packages in 347ms
# Installed 2 packages in 80ms
#  + aggdraw==1.3.19
#  + visualkeras==0.1.4
# C:\Users\dell\Documents\Coding\MERN Projects\Murf Project\Realtime-Sign-Language-Detection-Using-LSTM-Model\.venv\lib\site-packages\visualkeras\layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=664x591>

# %% [markdown]
# # Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'cat'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'cat'

# %% [markdown]
# # Save Weights

# %%
# model.save('./model.h5')
# model.save_weights('./model_weights.h5');
# The correct way to save the model and weights
# model.save('./model.h5')
# model.save_weights('./model_weights.h5')
model.save('./model.h5')
model.save_weights('./model.weights.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
del model

# %%
import tensorflow as tf
model = tf.keras.models.load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# model.load_weights('model_weights.h5')
model.load_weights('model.weights.h5')
# Out:
# C:\Users\dell\Documents\Coding\MERN Projects\Murf Project\Realtime-Sign-Language-Detection-Using-LSTM-Model\.venv\lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 32 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # Evaluation using Confusion Matrix

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[4, 0],
#         [0, 1]],
#
#        [[1, 0],
#         [0, 4]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # Realtime Test

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# iloveyou

# %%
# !uv pip install numpy --upgrade
# Out:
# Resolved 1 package in 90ms
# Audited 1 package in 0.68ms

# %%
# # import cv2
# # import numpy as np
# # import os
# # from matplotlib import pyplot as plt
# # import time
# # import mediapipe as mp
# # import tensorflow as tf

# # signs = ['hello', 'thanks', 'iloveyou']
# # actions = np.array(['hello', 'thanks', 'iloveyou'])


# # mp_holistic = mp.solutions.holistic # Holistic model
# # mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# # def mediapipe_detection(image, model):
# #     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
# #     image.flags.writeable = False                  # Convert image to not-writeable
# #     results = model.process(image)                 # Make prediction
# #     image.flags.writeable = True                   # Convert image to writeable 
# #     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
# #     return image, results

# # colors = [(245,117,16), (117,245,16), (16,117,245)]
# # def prob_viz(res, actions, input_frame, colors):
# #     output_frame = input_frame.copy()
# #     for num, prob in enumerate(res):
# #         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
# #         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
# #     return output_frame

# # def draw_styled_landmarks(image, results):
# #     # Draw face connections
# #     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
# #                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
# #                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
# #                              ) 
# #     # Draw pose connections
# #     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
# #                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
# #                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
# #                              ) 
# #     # Draw left hand connections
# #     mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
# #                              mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
# #                              mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
# #                              ) 
# #     # Draw right hand connections  
# #     mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
# #                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
# #                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
# #                              ) 
    
# # def extract_keypoints(results):
# #     pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
# #     face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
# #     lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
# #     rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
# #     return np.concatenate([pose, face, lh, rh])
    
# # # 1. New detection variables
# # sequence = []
# # sentence = []
# # predictions = []
# # threshold = 0.5

# # model = tf.keras.models.load_model('model.h5')
# # model.load_weights('model_weights.h5')
# # model.summary()

# # cap = cv2.VideoCapture(0)
# # # Set mediapipe model 
# # with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
# #     while cap.isOpened():

# #         # Read feed
# #         ret, frame = cap.read()

# #         # Make detections
# #         image, results = mediapipe_detection(frame, holistic)
# #         #print(results)
        
# #         # Draw landmarks
# #         draw_styled_landmarks(image, results)
        
# #         # 2. Prediction logic
# #         keypoints = extract_keypoints(results)
# #         sequence.append(keypoints)
# #         sequence = sequence[-30:]
        
# #         if len(sequence) == 30:
# #            # chnage
# #             res = model.predict(np.expand_dims(sequence, axis=0))[0]
            
# #             # below this changes 

            
# #             # Convert numpy prediction to Python list
# #         prediction_data = {
# #             "probabilities": res.tolist(),             # full probability distribution
# #             "predicted_label": actions[np.argmax(res)] # most likely sign
# # }

# # # Append to a global results array
# #         if 'results_array' not in globals():
# #             results_array = []
# #             results_array.append(prediction_data)

# #         print(prediction_data)  # optional: see it in terminal

# #             # above this changes



# #             #print(actions[np.argmax(res)])
# #             predictions.append(np.argmax(res))
            
            
# #         #3. Viz logic
# #             if np.unique(predictions[-10:])[0]==np.argmax(res): 
# #                 if res[np.argmax(res)] > threshold: 
                    
# #                     if len(sentence) > 0: 
# #                         if actions[np.argmax(res)] != sentence[-1]:
# #                             sentence.append(actions[np.argmax(res)])
# #                     else:
# #                         sentence.append(actions[np.argmax(res)])

# #             if len(sentence) > 5: 
# #                 sentence = sentence[-5:]

# #             # Viz probabilities
# #             #image = prob_viz(res, actions, image, colors)
            
# #         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
# #         cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
# #         #print(sentence)
# #         #word = sentence[-1:]
# #         #convert_to_audio(word[0]) if (len(word) != 0) else print("word not detected yet")
# #         #convert_to_audio(word[0])
        
# #         # Show to screen
# #         cv2.imshow('Realtime LSTM Sign Language Detection', image)

# #         # Break gracefully
# #         if cv2.waitKey(10) & 0xFF == ord('q'):
# #             break
# #     cap.release()
# #     cv2.destroyAllWindows
  

# # second code below 

# # import cv2
# # import numpy as np
# # import mediapipe as mp
# # import tensorflow as tf

# # signs = ['hello', 'thanks', 'iloveyou']
# # actions = np.array(['hello', 'thanks', 'iloveyou'])

# # mp_holistic = mp.solutions.holistic  # Holistic model
# # mp_drawing = mp.solutions.drawing_utils  # Drawing utilities


# # def mediapipe_detection(image, model):
# #     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # BGR → RGB
# #     image.flags.writeable = False
# #     results = model.process(image)  # Make prediction
# #     image.flags.writeable = True
# #     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # RGB → BGR
# #     return image, results


# # def draw_styled_landmarks(image, results):
# #     # Face
# #     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
# #                               mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
# #                               mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))
# #     # Pose
# #     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
# #                               mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
# #                               mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2))
# #     # Left hand
# #     mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
# #                               mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
# #                               mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2))
# #     # Right hand
# #     mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
# #                               mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
# #                               mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))


# # def extract_keypoints(results):
# #     pose = np.array([[res.x, res.y, res.z, res.visibility] for res in
# #                      results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33 * 4)
# #     face = np.array([[res.x, res.y, res.z] for res in
# #                      results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468 * 3)
# #     lh = np.array([[res.x, res.y, res.z] for res in
# #                    results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(
# #         21 * 3)
# #     rh = np.array([[res.x, res.y, res.z] for res in
# #                    results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(
# #         21 * 3)
# #     return np.concatenate([pose, face, lh, rh])


# # # Detection variables
# # sequence = []
# # sentence = []
# # predictions = []
# # threshold = 0.5
# # results_array = []  # global results storage

# # # Load model
# # model = tf.keras.models.load_model('model.h5')
# model.load_weights('model_weights.h5')
# model.summary()

# cap = cv2.VideoCapture(0)

# # Mediapipe holistic model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     while cap.isOpened():
#         ret, frame = cap.read()
#         image, results = mediapipe_detection(frame, holistic)

#         # Draw landmarks
#         draw_styled_landmarks(image, results)

#         # Extract keypoints
#         keypoints = extract_keypoints(results)
#         sequence.append(keypoints)
#         sequence = sequence[-30:]

#         if len(sequence) == 30:
#             res = model.predict(np.expand_dims(sequence, axis=0))[0]
#             predictions.append(np.argmax(res))

#             # Convert numpy prediction to Python list
#             prediction_data = {
#                 "probabilities": res.tolist(),
#                 "predicted_label": actions[np.argmax(res)]
#             }

#             # Save in results array
#             results_array.append(prediction_data)

#             # Print to terminal
#             print(prediction_data)

#             # Viz logic
#             if np.unique(predictions[-10:])[0] == np.argmax(res):
#                 if res[np.argmax(res)] > threshold:
#                     if len(sentence) > 0:
#                         if actions[np.argmax(res)] != sentence[-1]:
#                             sentence.append(actions[np.argmax(res)])
#                     else:
#                         sentence.append(actions[np.argmax(res)])

#             if len(sentence) > 5:
#                 sentence = sentence[-5:]

#         # Display text on video
#         cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
#         cv2.putText(image, ' '.join(sentence), (3, 30), cv2.FONT_HERSHEY_SIMPLEX,
#                     1, (255, 255, 255), 2, cv2.LINE_AA)

#         # Show video
#         cv2.imshow('Realtime LSTM Sign Language Detection', image)

#         # Break
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

# cap.release()
# cv2.destroyAllWindows()

# 3rd code 
import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf
import json
from collections import Counter

# ----------------------------
# Setup
# ----------------------------
actions = np.array(['hello', 'thanks', 'iloveyou'])
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

def draw_styled_landmarks(image, results):
    # Face
    mp_drawing.draw_landmarks(
        image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
        mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
        mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
    )
    # Pose
    mp_drawing.draw_landmarks(
        image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
        mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
    )
    # Left hand
    mp_drawing.draw_landmarks(
        image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
        mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
    )
    # Right hand
    mp_drawing.draw_landmarks(
        image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
        mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
    )

def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] 
                     for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] 
                     for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] 
                   for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] 
                   for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# ----------------------------
# Load Model
# ----------------------------
model = tf.keras.models.load_model('model.h5')
model.load_weights('model_weights.h5')

# ----------------------------
# Variables
# ----------------------------
sequence, sentence, predictions = [], [], []
threshold = 0.5
results_array = []   # <-- store all predictions here

# ----------------------------
# Capture Video
# ----------------------------
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Detections
        image, results = mediapipe_detection(frame, holistic)
        draw_styled_landmarks(image, results)

        # Extract keypoints
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        # Prediction
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]

            prediction_data = {
                "probabilities": res.tolist(),
                "predicted_label": actions[np.argmax(res)]
            }
            results_array.append(prediction_data)   # store in array
            print(prediction_data)                  # see live in terminal

            predictions.append(np.argmax(res))

            # Sentence building
            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] > threshold:
                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5:
                sentence = sentence[-5:]

        # Display
        cv2.rectangle(image, (0,0), (640,40), (245,117,16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

        cv2.imshow('Realtime LSTM Sign Language Detection', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# ----------------------------
# Save Final Results
# ----------------------------
cap.release()
cv2.destroyAllWindows()

# Majority vote for final output
# Majority vote for final output
all_labels = [p["predicted_label"] for p in results_array]

# Unique detected labels
unique_outputs = list(set(all_labels))

# Final output (majority vote, keep it if needed)
final_output = Counter(all_labels).most_common(1)[0][0] if all_labels else "No Prediction"

# Save both unique labels and majority vote
with open("results.json", "w") as f:
    json.dump({
        "all_predictions": results_array,
        "unique_outputs": unique_outputs,   # <-- stores ['thanks', 'iloveyou']
        "final_output": final_output
    }, f, indent=4)

print("✅ Final Output (majority):", final_output)
print("📁 Unique Outputs (all detected):", unique_outputs)
print("📁 Results saved to results.json")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
# {'probabilities': [1.0, 2.955366886842083e-21, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# {'probabilities': [1.0, 1.4853100648246517e-20, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# {'probabilities': [1.0, 4.1357143621879e-20, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# {'probabilities': [1.0, 1.35187523376825e-19, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# {'probabilities': [1.0, 1.2070305525157485e-16, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# {'probabilities': [1.0, 3.405610822103562e-14, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# {'probabilities': [0.9999942779541016, 5.755639904236887e-06, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# {'probabilities': [0.9999969005584717, 3.1104134450288257e-06, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# {'probabilities': [1.7763336472853553e-06, 0.9999982118606567, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# {'probabilities': [1.0, 1.9982300048567575e-13, 0.0], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# {'probabilities': [8.09508808664506e-18, 1.0, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# {'probabilities': [0.8191308975219727, 0.18086908757686615, 1.607876621556242e-33], 'predicted_label': 'hello'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# {'probabilities': [2.5575107836625493e-21, 1.0, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# {'probabilities': [3.484295518774161e-08, 1.0, 7.832003351879853e-26], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# {'probabilities': [2.2046990901884343e-25, 1.0, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# {'probabilities': [2.3419088392984122e-05, 0.999976634979248, 8.231171308072528e-16], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# {'probabilities': [1.5733552797290313e-35, 1.0, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# {'probabilities': [9.674076796241538e-33, 1.0, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# {'probabilities': [1.1601417761964804e-27, 1.0, 0.0], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# {'probabilities': [4.196465397399152e-06, 0.9999958276748657, 5.636539412295916e-12], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# {'probabilities': [1.2568848107523808e-18, 1.0, 3.5208178749925096e-31], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# {'probabilities': [5.007275705182224e-10, 1.0, 6.779568065319879e-16], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# {'probabilities': [2.0044556947595993e-07, 0.9999997615814209, 4.229802272326388e-12], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# {'probabilities': [2.0530529582174495e-05, 0.9999794960021973, 4.78652761870535e-09], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# {'probabilities': [0.00025728216860443354, 0.999742329120636, 3.981624843163445e-07], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# {'probabilities': [0.0009046607883647084, 0.9990909099578857, 4.4147282096673734e-06], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# {'probabilities': [0.00043533099233172834, 0.9995622038841248, 2.3976324428076623e-06], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# {'probabilities': [0.00027788159786723554, 0.9997206330299377, 1.4377906154550146e-06], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# {'probabilities': [0.00884934701025486, 0.9910321831703186, 0.00011838397767860442], 'predicted_label': 'thanks'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# {'probabilities': [3.736734299764066e-08, 2.521202588923188e-07, 0.9999997615814209], 'predicted_label': 'iloveyou'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
